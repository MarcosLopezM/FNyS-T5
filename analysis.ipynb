# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import norm
import scipy.stats as stats

# %%
df = pd.read_csv('./depths.csv')

# %%
data = df['Profundidad']

# %%
fig = plt.figure()
plt.hist(data, bins='auto', density=True, alpha=0.3, color='b', histtype='stepfilled')

mu, std = norm.fit(data)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, color='magenta', linewidth=1.25)
fig.patch.set_facecolor((0.98, 0.96, 0.88))
plt.gca().set_facecolor((0.98, 0.96, 0.88))
plt.title(rf"Resultados del ajuste: $\mu = ${mu:.2f}, $\sigma =$ {std:.2f}")

fig.savefig('./img/histogram_depths.pdf', dpi=500)
